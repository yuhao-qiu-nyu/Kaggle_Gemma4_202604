# %% [markdown]
# **NOTE: This submission utilizes the maximum inference time limit, so depending on the situation, a submission scoring error may occur.
#
# However, you can succeed by trying multiple times.**

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import json
import os
from multiprocessing import cpu_count

def read_json_file(file_path):
    """Read a JSON file and parse it into a Python object.

    Args:
        file_path (str): The path to the JSON file to read.

    Returns:
        dict: A dictionary object representing the JSON data.
        
    Raises:
        FileNotFoundError: If the specified file path does not exist.
        ValueError: If the specified file path does not contain valid JSON data.
    """
    try:
        # Open the file and load the JSON data into a Python object
        with open(file_path, 'r') as file:
            json_data = json.load(file)
        return json_data
    except FileNotFoundError:
        # Raise an error if the file path does not exist
        raise FileNotFoundError(f"File not found: {file_path}")
    except ValueError:
        # Raise an error if the file does not contain valid JSON data
        raise ValueError(f"Invalid JSON data in file: {file_path}")

cpu_count()
# Out:
# 4

# %%
train_df = pd.read_csv('/kaggle/input/asl-signs/train.csv')
print("\n\n... LOAD SIGN TO PREDICTION INDEX MAP FROM JSON FILE ...\n")
s2p_map = {k.lower():v for k,v in read_json_file(os.path.join("/kaggle/input/asl-signs/sign_to_prediction_index_map.json")).items()}
p2s_map = {v:k for k,v in read_json_file(os.path.join("/kaggle/input/asl-signs/sign_to_prediction_index_map.json")).items()}
encoder = lambda x: s2p_map.get(x.lower())
decoder = lambda x: p2s_map.get(x)
# print(s2p_map)
train_df['label'] = train_df.sign.map(encoder)
# Out:
# ... LOAD SIGN TO PREDICTION INDEX MAP FROM JSON FILE ...

# %%
ROWS_PER_FRAME = 543
MAX_LEN = 384
CROP_LEN = MAX_LEN
NUM_CLASSES  = 250
PAD = -100.
NOSE=[
    1,2,98,327
]
LNOSE = [98]
RNOSE = [327]
LIP = [ 0, 
    61, 185, 40, 39, 37, 267, 269, 270, 409,
    291, 146, 91, 181, 84, 17, 314, 405, 321, 375,
    78, 191, 80, 81, 82, 13, 312, 311, 310, 415,
    95, 88, 178, 87, 14, 317, 402, 318, 324, 308,
]
LLIP = [84,181,91,146,61,185,40,39,37,87,178,88,95,78,191,80,81,82]
RLIP = [314,405,321,375,291,409,270,269,267,317,402,318,324,308,415,310,311,312]

POSE = [500, 502, 504, 501, 503, 505, 512, 513]
LPOSE = [513,505,503,501]
RPOSE = [512,504,502,500]

REYE = [
    33, 7, 163, 144, 145, 153, 154, 155, 133,
    246, 161, 160, 159, 158, 157, 173,
]
LEYE = [
    263, 249, 390, 373, 374, 380, 381, 382, 362,
    466, 388, 387, 386, 385, 384, 398,
]

LHAND = np.arange(468, 489).tolist()
RHAND = np.arange(522, 543).tolist()

POINT_LANDMARKS = LIP + LHAND + RHAND + NOSE + REYE + LEYE #+POSE

NUM_NODES = len(POINT_LANDMARKS)
CHANNELS = 6*NUM_NODES

print(NUM_NODES)
print(CHANNELS)

def tf_nan_mean(x, axis=0, keepdims=False):
    return tf.reduce_sum(tf.where(tf.math.is_nan(x), tf.zeros_like(x), x), axis=axis, keepdims=keepdims) / tf.reduce_sum(tf.where(tf.math.is_nan(x), tf.zeros_like(x), tf.ones_like(x)), axis=axis, keepdims=keepdims)

def tf_nan_std(x, center=None, axis=0, keepdims=False):
    if center is None:
        center = tf_nan_mean(x, axis=axis,  keepdims=True)
    d = x - center
    return tf.math.sqrt(tf_nan_mean(d * d, axis=axis, keepdims=keepdims))

class Preprocess(tf.keras.layers.Layer):
    def __init__(self, max_len=MAX_LEN, point_landmarks=POINT_LANDMARKS, **kwargs):
        super().__init__(**kwargs)
        self.max_len = max_len
        self.point_landmarks = point_landmarks

    def call(self, inputs):
        if tf.rank(inputs) == 3:
            x = inputs[None,...]
        else:
            x = inputs
        
        mean = tf_nan_mean(tf.gather(x, [17], axis=2), axis=[1,2], keepdims=True)
        mean = tf.where(tf.math.is_nan(mean), tf.constant(0.5,x.dtype), mean)
        x = tf.gather(x, self.point_landmarks, axis=2) #N,T,P,C
        std = tf_nan_std(x, center=mean, axis=[1,2], keepdims=True)
        
        x = (x - mean)/std

        if self.max_len is not None:
            x = x[:,:self.max_len]
        length = tf.shape(x)[1]
        x = x[...,:2]

        dx = tf.cond(tf.shape(x)[1]>1,lambda:tf.pad(x[:,1:] - x[:,:-1], [[0,0],[0,1],[0,0],[0,0]]),lambda:tf.zeros_like(x))

        dx2 = tf.cond(tf.shape(x)[1]>2,lambda:tf.pad(x[:,2:] - x[:,:-2], [[0,0],[0,2],[0,0],[0,0]]),lambda:tf.zeros_like(x))

        x = tf.concat([
            tf.reshape(x, (-1,length,2*len(self.point_landmarks))),
            tf.reshape(dx, (-1,length,2*len(self.point_landmarks))),
            tf.reshape(dx2, (-1,length,2*len(self.point_landmarks))),
        ], axis = -1)
        
        x = tf.where(tf.math.is_nan(x),tf.constant(0.,x.dtype),x)
        
        return x
# Out:
# 118
# 708

# %%
class ECA(tf.keras.layers.Layer):
    def __init__(self, kernel_size=5, **kwargs):
        super().__init__(**kwargs)
        self.supports_masking = True
        self.kernel_size = kernel_size
        self.conv = tf.keras.layers.Conv1D(1, kernel_size=kernel_size, strides=1, padding="same", use_bias=False)

    def call(self, inputs, mask=None):
        nn = tf.keras.layers.GlobalAveragePooling1D()(inputs, mask=mask)
        nn = tf.expand_dims(nn, -1)
        nn = self.conv(nn)
        nn = tf.squeeze(nn, -1)
        nn = tf.nn.sigmoid(nn)
        nn = nn[:,None,:]
        return inputs * nn

class LateDropout(tf.keras.layers.Layer):
    def __init__(self, rate, noise_shape=None, start_step=0, **kwargs):
        super().__init__(**kwargs)
        self.supports_masking = True
        self.rate = rate
        self.start_step = start_step
        self.dropout = tf.keras.layers.Dropout(rate, noise_shape=noise_shape)
      
    def build(self, input_shape):
        super().build(input_shape)
        agg = tf.VariableAggregation.ONLY_FIRST_REPLICA
        self._train_counter = tf.Variable(0, dtype="int64", aggregation=agg, trainable=False)

    def call(self, inputs, training=False):
        x = tf.cond(self._train_counter < self.start_step, lambda:inputs, lambda:self.dropout(inputs, training=training))
        if training:
            self._train_counter.assign_add(1)
        return x

class CausalDWConv1D(tf.keras.layers.Layer):
    def __init__(self, 
        kernel_size=17,
        dilation_rate=1,
        use_bias=False,
        depthwise_initializer='glorot_uniform',
        name='', **kwargs):
        super().__init__(name=name,**kwargs)
        self.causal_pad = tf.keras.layers.ZeroPadding1D((dilation_rate*(kernel_size-1),0),name=name + '_pad')
        self.dw_conv = tf.keras.layers.DepthwiseConv1D(
                            kernel_size,
                            strides=1,
                            dilation_rate=dilation_rate,
                            padding='valid',
                            use_bias=use_bias,
                            depthwise_initializer=depthwise_initializer,
                            name=name + '_dwconv')
        self.supports_masking = True
        
    def call(self, inputs):
        x = self.causal_pad(inputs)
        x = self.dw_conv(x)
        return x

def Conv1DBlock(channel_size,
          kernel_size,
          dilation_rate=1,
          drop_rate=0.0,
          expand_ratio=2,
          se_ratio=0.25,
          activation='swish',
          name=None):
    '''
    efficient conv1d block, @hoyso48
    '''
    if name is None:
        name = str(tf.keras.backend.get_uid("mbblock"))
    # Expansion phase
    def apply(inputs):
        channels_in = tf.keras.backend.int_shape(inputs)[-1]
        channels_expand = channels_in * expand_ratio

        skip = inputs

        x = tf.keras.layers.Dense(
            channels_expand,
            use_bias=True,
            activation=activation,
            name=name + '_expand_conv')(inputs)

        # Depthwise Convolution
        x = CausalDWConv1D(kernel_size,
            dilation_rate=dilation_rate,
            use_bias=False,
            name=name + '_dwconv')(x)

        x = tf.keras.layers.BatchNormalization(momentum=0.95, name=name + '_bn')(x)

        x  = ECA()(x)

        x = tf.keras.layers.Dense(
            channel_size,
            use_bias=True,
            name=name + '_project_conv')(x)

        if drop_rate > 0:
            x = tf.keras.layers.Dropout(drop_rate, noise_shape=(None,1,1), name=name + '_drop')(x)

        if (channels_in == channel_size):
            x = tf.keras.layers.add([x, skip], name=name + '_add')
        return x

    return apply

# %%
class MultiHeadSelfAttention(tf.keras.layers.Layer):
    def __init__(self, dim=256, num_heads=4, dropout=0, **kwargs):
        super().__init__(**kwargs)
        self.dim = dim
        self.scale = self.dim ** -0.5
        self.num_heads = num_heads
        self.qkv = tf.keras.layers.Dense(3 * dim, use_bias=False)
        self.drop1 = tf.keras.layers.Dropout(dropout)
        self.proj = tf.keras.layers.Dense(dim, use_bias=False)
        self.supports_masking = True

    def call(self, inputs, mask=None):
        qkv = self.qkv(inputs)
        qkv = tf.keras.layers.Permute((2, 1, 3))(tf.keras.layers.Reshape((-1, self.num_heads, self.dim * 3 // self.num_heads))(qkv))
        q, k, v = tf.split(qkv, [self.dim // self.num_heads] * 3, axis=-1)

        attn = tf.matmul(q, k, transpose_b=True) * self.scale

        if mask is not None:
            mask = mask[:, None, None, :]

        attn = tf.keras.layers.Softmax(axis=-1)(attn, mask=mask)
        attn = self.drop1(attn)

        x = attn @ v
        x = tf.keras.layers.Reshape((-1, self.dim))(tf.keras.layers.Permute((2, 1, 3))(x))
        x = self.proj(x)
        return x


def TransformerBlock(dim=256, num_heads=4, expand=4, attn_dropout=0.2, drop_rate=0.2, activation='swish'):
    def apply(inputs):
        x = inputs
        x = tf.keras.layers.BatchNormalization(momentum=0.95)(x)
        x = MultiHeadSelfAttention(dim=dim,num_heads=num_heads,dropout=attn_dropout)(x)
        x = tf.keras.layers.Dropout(drop_rate, noise_shape=(None,1,1))(x)
        x = tf.keras.layers.Add()([inputs, x])
        attn_out = x

        x = tf.keras.layers.BatchNormalization(momentum=0.95)(x)
        x = tf.keras.layers.Dense(dim*expand, use_bias=False, activation=activation)(x)
        x = tf.keras.layers.Dense(dim, use_bias=False)(x)
        x = tf.keras.layers.Dropout(drop_rate, noise_shape=(None,1,1))(x)
        x = tf.keras.layers.Add()([attn_out, x])
        return x
    return apply

# %%
def get_model(max_len=MAX_LEN, dropout_step=0, dim=192):
    inp = tf.keras.Input((max_len,CHANNELS))
    #x = tf.keras.layers.Masking(mask_value=PAD,input_shape=(max_len,CHANNELS))(inp) #we don't need masking layer with inference
    x = inp
    ksize = 17
    x = tf.keras.layers.Dense(dim, use_bias=False,name='stem_conv')(x)
    x = tf.keras.layers.BatchNormalization(momentum=0.95,name='stem_bn')(x)

    x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
    x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
    x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
    x = TransformerBlock(dim,expand=2)(x)

    x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
    x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
    x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
    x = TransformerBlock(dim,expand=2)(x)

    if dim == 384: #for the 4x sized model
        x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
        x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
        x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
        x = TransformerBlock(dim,expand=2)(x)

        x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
        x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
        x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
        x = TransformerBlock(dim,expand=2)(x)

    x = tf.keras.layers.Dense(dim*2,activation=None,name='top_conv')(x)
    x = tf.keras.layers.GlobalAveragePooling1D()(x)
    x = LateDropout(0.8, start_step=dropout_step)(x)
    x = tf.keras.layers.Dense(NUM_CLASSES,name='classifier')(x)
    return tf.keras.Model(inp, x)

# %%
models_path = [
              '/kaggle/input/islr-models/islr-fp16-192-8-seed42-foldall-last.h5', #comment out other weights to check single model score
               '/kaggle/input/islr-models/islr-fp16-192-8-seed43-foldall-last.h5',
               '/kaggle/input/islr-models/islr-fp16-192-8-seed44-foldall-last.h5',
               #'/kaggle/input/islr-models/islr-fp16-192-8-seed45-foldall-last.h5',
              ]
models = [get_model() for _ in models_path]
for model,path in zip(models,models_path):
    model.load_weights(path)
models[0].summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_7 (InputLayer)           [(None, 384, 708)]   0           []
#
#  stem_conv (Dense)              (None, 384, 192)     135936      ['input_7[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 384, 192)     768         ['stem_conv[0][0]']
#
#  37_expand_conv (Dense)         (None, 384, 384)     74112       ['stem_bn[0][0]']
#
#  37_dwconv (CausalDWConv1D)     (None, 384, 384)     6528        ['37_expand_conv[0][0]']
#
#  37_bn (BatchNormalization)     (None, 384, 384)     1536        ['37_dwconv[0][0]']
#
#  eca_36 (ECA)                   (None, 384, 384)     5           ['37_bn[0][0]']
#
#  37_project_conv (Dense)        (None, 384, 192)     73920       ['eca_36[0][0]']
#
#  37_drop (Dropout)              (None, 384, 192)     0           ['37_project_conv[0][0]']
#
# ...

# %%
ROWS_PER_FRAME = 543  # number of landmarks per frame
def load_relevant_data_subset(pq_path):
    data_columns = ['x', 'y', 'z']
    data = pd.read_parquet('/kaggle/input/asl-signs/' + pq_path, columns=data_columns)
    n_frames = int(len(data) / ROWS_PER_FRAME)
    data = data.values.reshape(n_frames, ROWS_PER_FRAME, len(data_columns))
    return data.astype(np.float32)

# %%
tflite_keras_model = TFLiteModel(islr_models=models)
demo_output = tflite_keras_model(load_relevant_data_subset(train_df.path[0]))["outputs"]
decoder(np.argmax(demo_output.numpy(), axis=-1))
# Out:
# 'blow'

# %% [markdown]
# 新增 ensemble + top-k 产品输出函数

# %% [markdown]
# 第一步：从 train.csv 取一条样本路径

# %%
import pandas as pd

train_df = pd.read_csv('/kaggle/input/asl-signs/train.csv')
train_df.head()
# Out:
#                                             path  participant_id  sequence_id  \
# 0  train_landmark_files/26734/1000035562.parquet           26734   1000035562
# 1  train_landmark_files/28656/1000106739.parquet           28656   1000106739
# 2   train_landmark_files/16069/100015657.parquet           16069    100015657
# 3  train_landmark_files/25571/1000210073.parquet           25571   1000210073
# 4  train_landmark_files/62590/1000240708.parquet           62590   1000240708
#
#     sign
# 0   blow
# 1   wait
# 2  cloud
# 3   bird
# 4   owie

# %% [markdown]
# 第二步：读一条 parquet，整理成 (T, 543, 3)

# %%
import numpy as np
import pandas as pd

ROWS_PER_FRAME = 543

def load_raw_landmarks_from_train(idx=0):
    row = train_df.iloc[idx]
    parquet_path = f"/kaggle/input/asl-signs/{row['path']}"
    df = pd.read_parquet(parquet_path)

    # 每帧应该有 543 行 landmark
    n_frames = len(df) // ROWS_PER_FRAME
    arr = df[['x', 'y', 'z']].values.reshape(n_frames, ROWS_PER_FRAME, 3)

    return arr, row['sign'], parquet_path

raw_landmarks, true_sign, sample_path = load_raw_landmarks_from_train(0)

print("true sign:", true_sign)
print("sample path:", sample_path)
print("raw_landmarks shape:", raw_landmarks.shape)
# Out:
# true sign: blow
# sample path: /kaggle/input/asl-signs/train_landmark_files/26734/1000035562.parquet
# raw_landmarks shape: (23, 543, 3)

# %%
import json
import numpy as np
import tensorflow as tf

def ensemble_predict_logits(models, x):
    """
    x: Tensor, shape (B, MAX_LEN, CHANNELS)
    """
    logits_list = []
    for model in models:
        logits = model(x, training=False)
        logits_list.append(logits)
    logits = tf.reduce_mean(tf.stack(logits_list, axis=0), axis=0)
    return logits

def logits_to_product_output(logits, p2s_map, topk=3):
    """
    logits: Tensor, shape (B, NUM_CLASSES)
    """
    probs = tf.nn.softmax(logits, axis=-1).numpy()
    topk_probs, topk_ids = tf.math.top_k(probs, k=topk)
    topk_probs = topk_probs.numpy()
    topk_ids = topk_ids.numpy()

    outputs = []
    for i in range(len(topk_ids)):
        topk_predictions = []
        for j in range(topk):
            cls_id = int(topk_ids[i, j])
            label = p2s_map[cls_id]
            prob = float(topk_probs[i, j])
            topk_predictions.append({
                "rank": j + 1,
                "label": label,
                "prob": prob
            })

        best_prob = float(topk_probs[i, 0])
        confidence = "high"
        if best_prob < 0.80:
            confidence = "medium"
        if best_prob < 0.50:
            confidence = "low"

        outputs.append({
            "predicted_label": topk_predictions[0]["label"],
            "predicted_prob": topk_predictions[0]["prob"],
            "confidence": confidence,
            "topk_predictions": topk_predictions,
            "task_type": "isolated_sign_recognition"
        })

    return outputs

# %% [markdown]
# 新增“从原始 landmarks 到产品结果”的接口

# %%
preprocess_layer = Preprocess(max_len=MAX_LEN)

def prepare_single_sample(raw_landmarks):
    """
    raw_landmarks: numpy.ndarray or Tensor, shape (T, 543, 3)
    return: Tensor, shape (1, MAX_LEN, CHANNELS)
    """
    x = tf.convert_to_tensor(raw_landmarks, dtype=tf.float32)

    # 用原 notebook 的 Preprocess
    x = preprocess_layer(x)[0]           # (T', CHANNELS)
    x = tf.expand_dims(x, axis=0)        # (1, T', CHANNELS)

    seq_len = x.shape[1]
    if seq_len < MAX_LEN:
        pad_len = MAX_LEN - seq_len
        pad_tensor = tf.ones((1, pad_len, CHANNELS), dtype=x.dtype) * PAD
        x = tf.concat([x, pad_tensor], axis=1)
    else:
        x = x[:, :MAX_LEN, :]

    return x

def predict_product_result(models, raw_landmarks, p2s_map, topk=3):
    x = prepare_single_sample(raw_landmarks)
    logits = ensemble_predict_logits(models, x)
    result = logits_to_product_output(logits, p2s_map, topk=topk)[0]
    return result

# %% [markdown]
# 新增gemma4paylod和prompt生成器

# %%
def build_gemma_payload(pred_result, user_goal=None, history_errors=None):
    payload = {
        "task_type": pred_result["task_type"],
        "predicted_label": pred_result["predicted_label"],
        "predicted_prob": pred_result["predicted_prob"],
        "confidence": pred_result["confidence"],
        "topk_predictions": pred_result["topk_predictions"],
        "user_goal": user_goal if user_goal is not None else "practice sign language",
        "history_errors": history_errors if history_errors is not None else []
    }
    return payload

def build_gemma_prompt(payload):
    prompt = f"""
You are a friendly sign language learning coach.

A gesture recognition system has analyzed the user's sign attempt.
Please provide:
1. A short recognition summary
2. A brief correction or explanation
3. A supportive encouragement sentence
4. One next-step practice suggestion

Recognition result:
{json.dumps(payload, ensure_ascii=False, indent=2)}

Requirements:
- Be concise
- Be supportive and instructional
- If confidence is low, mention uncertainty carefully
- Use the top predictions to explain possible confusion
"""
    return prompt
    print(prompt)

# %% [markdown]
# 5）新增批量导出 JSONL / CSV

# %%
import pandas as pd

def export_product_results_jsonl(results, output_path="/kaggle/working/predictions_for_gemma.jsonl"):
    with open(output_path, "w", encoding="utf-8") as f:
        for item in results:
            f.write(json.dumps(item, ensure_ascii=False) + "\n")
    print("saved:", output_path)

def export_product_results_csv(results, output_path="/kaggle/working/predictions_for_gemma.csv"):
    rows = []
    for item in results:
        row = {
            "predicted_label": item["predicted_label"],
            "predicted_prob": item["predicted_prob"],
            "confidence": item["confidence"],
        }
        for pred in item["topk_predictions"]:
            row[f"top{pred['rank']}_label"] = pred["label"]
            row[f"top{pred['rank']}_prob"] = pred["prob"]
        rows.append(row)

    df = pd.DataFrame(rows)
    df.to_csv(output_path, index=False)
    print("saved:", output_path)
    return df

# %%
print(type(models), len(models))
print(type(p2s_map), len(p2s_map))
# Out:
# <class 'list'> 3
# <class 'dict'> 250

# %%
pred_result = predict_product_result(
    models=models,
    raw_landmarks=raw_landmarks,
    p2s_map=p2s_map,
    topk=3
)

print(json.dumps(pred_result, ensure_ascii=False, indent=2))
# Out:
# {
#   "predicted_label": "grandma",
#   "predicted_prob": 1.0,
#   "confidence": "high",
#   "topk_predictions": [
#     {
#       "rank": 1,
#       "label": "grandma",
#       "prob": 1.0
#     },
#     {
#       "rank": 2,
#       "label": "grandpa",
#       "prob": 7.648867533572976e-22
#     },
#     {
#       "rank": 3,
#       "label": "another",
#       "prob": 2.513616899389239e-37
#     }
#   ],
#   "task_type": "isolated_sign_recognition"
# }

# %% [markdown]
# 构造gemma4输入

# %%
gemma_payload = build_gemma_payload(
    pred_result,
    user_goal="learn daily ASL vocabulary",
    history_errors=[]
)

gemma_prompt = build_gemma_prompt(gemma_payload)

print(json.dumps(gemma_payload, ensure_ascii=False, indent=2))
print()
print("=== Gemma Prompt ===")
print(gemma_prompt)
# Out:
# {
#   "task_type": "isolated_sign_recognition",
#   "predicted_label": "grandma",
#   "predicted_prob": 1.0,
#   "confidence": "high",
#   "topk_predictions": [
#     {
#       "rank": 1,
#       "label": "grandma",
#       "prob": 1.0
#     },
#     {
#       "rank": 2,
#       "label": "grandpa",
#       "prob": 7.648867533572976e-22
#     },
#     {
#       "rank": 3,
#       "label": "another",
#       "prob": 2.513616899389239e-37
#     }
#   ],
#   "user_goal": "learn daily ASL vocabulary",
#   "history_errors": []
# }
#
# === Gemma Prompt ===
#
# You are a friendly sign language learning coach.
#
# A gesture recognition system has analyzed the user's sign attempt.
# Please provide:
# 1. A short recognition summary
# 2. A brief correction or explanation
# 3. A supportive encouragement sentence
# 4. One next-step practice suggestion
#
# Recognition result:
# {
#   "task_type": "isolated_sign_recognition",
#   "predicted_label": "grandma",
#   "predicted_prob": 1.0,
# ...

# %% [markdown]
# **#下面接入gemma4#**

# %% [markdown]
# Cell 4：构造给 Gemma 4 的 payload 和 prompt

# %%
import json

def build_gemma_payload(pred_result, true_sign=None, user_goal=None, history_errors=None):
    return {
        "task_type": pred_result["task_type"],
        "predicted_label": pred_result["predicted_label"],
        "predicted_prob": pred_result["predicted_prob"],
        "confidence": pred_result["confidence"],
        "topk_predictions": pred_result["topk_predictions"],
        "true_sign_for_debug": true_sign,
        "user_goal": user_goal if user_goal is not None else "practice sign language",
        "history_errors": history_errors if history_errors is not None else []
    }

gemma_payload = build_gemma_payload(
    pred_result,
    true_sign=true_sign if "true_sign" in globals() else None,
    user_goal="learn family-related ASL vocabulary",
    history_errors=["grandpa", "mother"]
)

print(json.dumps(gemma_payload, ensure_ascii=False, indent=2))
# Out:
# {
#   "task_type": "isolated_sign_recognition",
#   "predicted_label": "grandma",
#   "predicted_prob": 1.0,
#   "confidence": "high",
#   "topk_predictions": [
#     {
#       "rank": 1,
#       "label": "grandma",
#       "prob": 1.0
#     },
#     {
#       "rank": 2,
#       "label": "grandpa",
#       "prob": 7.648867533572976e-22
#     },
#     {
#       "rank": 3,
#       "label": "another",
#       "prob": 2.513616899389239e-37
#     }
#   ],
#   "true_sign_for_debug": "blow",
#   "user_goal": "learn family-related ASL vocabulary",
#   "history_errors": [
#     "grandpa",
#     "mother"
#   ]
# }

# %%
SYSTEM_PROMPT = """
你是一名友好、耐心、鼓励式的手语学习教练。

你的任务是根据手语识别模型的结果，为学习者生成简短、清晰、有帮助的反馈。

请始终输出以下四部分：
1. 识别总结
2. 纠错或解释
3. 鼓励反馈
4. 下一步练习建议

要求：
- 语言简洁
- 语气温和
- 有教学感
- 不要使用技术术语
- 如果置信度低，要明确说明模型可能不确定
- 如果 top-k 里有容易混淆的词，要顺带指出
"""

USER_PROMPT = f"""
下面是手语识别模型对用户一次手势尝试的识别结果：

{json.dumps(gemma_payload, ensure_ascii=False, indent=2)}

请你基于这些结果，生成一段适合学习者阅读的反馈，包含：
- 识别总结
- 纠错或解释
- 鼓励反馈
- 下一步练习建议
"""

messages = [
    {"role": "user", "content": f"{SYSTEM_PROMPT}\n\n{USER_PROMPT}"}
]

print(messages[0]["content"])
# Out:
# 你是一名友好、耐心、鼓励式的手语学习教练。
#
# 你的任务是根据手语识别模型的结果，为学习者生成简短、清晰、有帮助的反馈。
#
# 请始终输出以下四部分：
# 1. 识别总结
# 2. 纠错或解释
# 3. 鼓励反馈
# 4. 下一步练习建议
#
# 要求：
# - 语言简洁
# - 语气温和
# - 有教学感
# - 不要使用技术术语
# - 如果置信度低，要明确说明模型可能不确定
# - 如果 top-k 里有容易混淆的词，要顺带指出
#
#
#
# 下面是手语识别模型对用户一次手势尝试的识别结果：
#
# {
#   "task_type": "isolated_sign_recognition",
#   "predicted_label": "grandma",
#   "predicted_prob": 1.0,
#   "confidence": "high",
#   "topk_predictions": [
#     {
#       "rank": 1,
#       "label": "grandma",
#       "prob": 1.0
#     },
#     {
#       "rank": 2,
#       "label": "grandpa",
#       "prob": 7.648867533572976e-22
#     },
#     {
#       "rank": 3,
#       "label": "another",
#       "prob": 2.513616899389239e-37
#     }
#   ],
#   "true_sign_for_debug": "blow",
#   "user_goal": "learn family-related ASL vocabulary",
#   "history_errors": [
#     "grandpa",
#     "mother"
#   ]
# }
#
# 请你基于这些结果，生成一段适合学习者阅读的反馈，包含：
# - 识别总结
# - 纠错或解释
# - 鼓励反馈
# - 下一步练习建议

# %%
import json

gemma_payload = {
    "task_type": pred_result["task_type"],
    "predicted_label": pred_result["predicted_label"],
    "predicted_prob": pred_result["predicted_prob"],
    "confidence": pred_result["confidence"],
    "topk_predictions": pred_result["topk_predictions"],
    "user_goal": "learn family-related ASL vocabulary",
    "history_errors": ["grandpa", "mother"]
}

with open("/kaggle/working/gemma_payload.json", "w", encoding="utf-8") as f:
    json.dump(gemma_payload, f, ensure_ascii=False, indent=2)

print("saved: /kaggle/working/gemma_payload.json")
print(json.dumps(gemma_payload, ensure_ascii=False, indent=2))
# Out:
# saved: /kaggle/working/gemma_payload.json
# {
#   "task_type": "isolated_sign_recognition",
#   "predicted_label": "grandma",
#   "predicted_prob": 1.0,
#   "confidence": "high",
#   "topk_predictions": [
#     {
#       "rank": 1,
#       "label": "grandma",
#       "prob": 1.0
#     },
#     {
#       "rank": 2,
#       "label": "grandpa",
#       "prob": 7.648867533572976e-22
#     },
#     {
#       "rank": 3,
#       "label": "another",
#       "prob": 2.513616899389239e-37
#     }
#   ],
#   "user_goal": "learn family-related ASL vocabulary",
#   "history_errors": [
#     "grandpa",
#     "mother"
#   ]
# }
